# %% [markdown]
# **DEMO TOOL FOR KINGCOM**

# %%
import modules_for_demo as mylib
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# This demo Jupyter notebook allows you to test the influencer ranking system.
#
# You can enter single query terms, such as 'macaron' or 'charcuterie'.
#
# The output consists of an interactive bubble map. Each bubble represents one Instagram user profile, with the following attributes:
# - position: the profile is projected from a high-dimensional semantic space onto the 2D plane for easier visualisation
# - size : denotes social influence, the larger the more influent
# - colour : the darker the red, the more related to the topic of interest
# That best candidate has the largest bubble of the darkest colour. The balance between darkness and bubble size is a matter of choice, and can be calibrated in the system.
#
# Hovering with the mouse over each bubble will give extra information on a user, which is also found in the table of results.
#
# The second output is a table of results, with in order of columns
# - Instagram profile id
# - final_measure: this is the overall score obtained by combining the social influence score and the topic relatedness score
# - likes: number of likes, taken directly from Instagram profile
# - followers: number of followers, taken directly from Instagram profile
# - likesperday: average likes per day over the last 300 Instagram posts
#
# NB
# The table display the best 10 profiles, while the bubble map contains the best 100.
# This demo is running on 10 000 profiles.

# %%
mylib.launch_campaign_about('spaghetti')
# Out:
# <div id="f9f94328-7e9c-47f2-9df9-eaf8147e40db" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f9f94328-7e9c-47f2-9df9-eaf8147e40db", [{"type": "scatter", "x": [-2.1637361294915096, -2.300992969790276, -2.0062179197306556, -1.603933238618113], "y": [-1.167978060774658, -1.1726227683131734, -1.0654950682217117, -0.8208850106145801], "text": ["instagram URL: http://instagram.com/web/friendships/270713045/follow/<br>instagram ID: 270713045<br>final measure: 0.34<br>likes: 473877.0<br>followers: 190294.0<br>likesperday: 3145.0<br>", "instagram URL: http://instagram.com/web/friendships/550862816/follow/<br>instagram ID: 550862816<br>final measure: 0.3<br>likes: 479876.0<br>followers: 32049.0<br>likesperday: 1086.0<br>", "instagram URL: http://instagram.com/web/friendships/2533019771/follow/<br>instagram
# ...

# %% [markdown]
# Le premier profil pour la requête *fruits* est [*juicenantes*](https://www.instagram.com/juicenantes/), qui ne mentionne d'ailleurs guère les fruits (mais qui en est plein !)
#
# Ceci illustre bien l'approche: analyse sémantique du texte (pas par mots-clés), des images, des hashtags. Ce qui compte est bien le sens et le domaine lexical, pas les termes exacts employés.

# %%
mylib.launch_campaign_about('fruits')
# Out:
# <div id="aa52c59d-418b-455f-bd3b-e940c5431683" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aa52c59d-418b-455f-bd3b-e940c5431683", [{"type": "scatter", "x": [-1.8859846032679797, -2.1638426848079146, -2.076932589667978, -2.0062497793612883, -2.3010615791614355, -2.1207198161086467, -1.603928275569907, -2.038590931004405], "y": [-1.003324608995774, -1.1679098915826176, -1.0353251139237327, -1.0654333622090768, -1.172496954287945, -0.9512549397879586, -0.8208581459009168, -0.9740032769957504], "text": ["instagram URL: http://instagram.com/web/friendships/2212133610/follow/<br>instagram ID: 2212133610<br>final measure: 0.42<br>likes: 381526.0<br>followers: 105412.0<br>likesperday: 1078.0<br>", "instagram URL: http://instagram.com/web/friendships/270713045/follow/<br>instagram ID: 270713045<br>final
# ...

# %%
mylib.launch_campaign_about('cupcakes')
# Out:
# <div id="b19aba78-e8b7-47f4-a5f9-42ab8f9998eb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b19aba78-e8b7-47f4-a5f9-42ab8f9998eb", [{"type": "scatter", "x": [-2.16370978769843, -2.300971576660852, -2.076841296418843, -1.8857178769550602, -2.184420147620981, -2.0062074001631722, -2.120721527812827, -2.0386014686587983], "y": [-1.1678309283833355, -1.1725097358651277, -1.0352781657721248, -1.0029803972538642, -0.8480546593018322, -1.0654580238919475, -0.9513396492444619, -0.9741011413600184], "text": ["instagram URL: http://instagram.com/web/friendships/270713045/follow/<br>instagram ID: 270713045<br>final measure: 0.52<br>likes: 473877.0<br>followers: 190294.0<br>likesperday: 3145.0<br>", "instagram URL: http://instagram.com/web/friendships/550862816/follow/<br>instagram ID: 550862816<br>final me
# ...

# %% [markdown]
# La première réponse pour "charcuterie" est l'utilisateur *lyon_gastronomie*.
#
# Un des profils les plus sémantiquement proches (bulle très foncée) est [*so_food_toulouse*](http://instagram.com/web/friendships/2226115366/follow/).

# %%
mylib.launch_campaign_about('charcuterie')
# Out:
# <div id="5b86aef6-b916-4b95-b4e9-0a298583f19e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5b86aef6-b916-4b95-b4e9-0a298583f19e", [{"type": "scatter", "x": [-2.3011797383480364, -2.1638820829522385, -2.0062645773503647, -2.0769061727466327, -1.6039479190129087, -2.120683772507298, -1.8858297711395051], "y": [-1.1725712609752572, -1.1678516738104412, -1.0654515264140223, -1.035234938419389, -0.8209203712593053, -0.9512605223965318, -1.0028903363196524], "text": ["instagram URL: http://instagram.com/web/friendships/550862816/follow/<br>instagram ID: 550862816<br>final measure: 0.44<br>likes: 479876.0<br>followers: 32049.0<br>likesperday: 1086.0<br>", "instagram URL: http://instagram.com/web/friendships/270713045/follow/<br>instagram ID: 270713045<br>final measure: 0.42<br>likes: 473877.0<br>follo
# ...

# %% [markdown]
# La requête "vin" donne le même profil *lyon_gastronomie* en tête (cf "jury de vins" dans la description de son profil), surtout en raison de ses likes. Le 2è profil listé possède plus de followers, et il est également très proche en termes sémantiques.

# %%
mylib.launch_campaign_about('vin')
# Out:
# <div id="d9873be2-516d-447d-82a5-1a581e3d3804" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d9873be2-516d-447d-82a5-1a581e3d3804", [{"type": "scatter", "x": [-1.8857801484359689, -2.1637032812750108, -2.3009724368857385, -2.076818455019934], "y": [-1.0028320129145891, -1.1676376452473072, -1.1723281228230422, -1.0351278121435077], "text": ["instagram URL: http://instagram.com/web/friendships/2212133610/follow/<br>instagram ID: 2212133610<br>final measure: 0.21<br>likes: 381526.0<br>followers: 105412.0<br>likesperday: 1078.0<br>", "instagram URL: http://instagram.com/web/friendships/270713045/follow/<br>instagram ID: 270713045<br>final measure: 0.18<br>likes: 473877.0<br>followers: 190294.0<br>likesperday: 3145.0<br>", "instagram URL: http://instagram.com/web/friendships/550862816/follow/<br>inst
# ...

# %% [markdown]
# La cellule suivante permet une entrée interactive au clavier:

# %%
mylib.launch_campaign_about('anis')
# Out:
# <div id="7e33b877-1805-4f08-89cf-63ea409ac6d4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7e33b877-1805-4f08-89cf-63ea409ac6d4", [{"type": "scatter", "x": [-1.8858059937370033, -2.076849676688171, -2.163708954312396, -1.6039270033112798, -2.300964474060173, -2.006193270713032], "y": [-1.002934785947876, -1.0352097552860364, -1.167688884329519, -0.8209113730840116, -1.1723597122029372, -1.065395662151015], "text": ["instagram URL: http://instagram.com/web/friendships/2212133610/follow/<br>instagram ID: 2212133610<br>final measure: 0.42<br>likes: 381526.0<br>followers: 105412.0<br>likesperday: 1078.0<br>", "instagram URL: http://instagram.com/web/friendships/1280794066/follow/<br>instagram ID: 1280794066<br>final measure: 0.31<br>likes: 1322543.0<br>followers: 253193.0<br>likesperday: 7602.0<br>
# ...

# %%
mylib.launch_campaign_about('patisserie')
# Out:
# <div id="4d088c61-8691-426d-8386-f8d95cc07438" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4d088c61-8691-426d-8386-f8d95cc07438", [{"type": "scatter", "x": [-2.0770819575973998, -2.3012172189323126, -1.886107923996489, -2.1639190274912004, -2.184467305994837, -2.006274478025836, -2.1207305073346268, -2.038605792433768], "y": [-1.0356879148918106, -1.1728892651775926, -1.0037307012660313, -1.16812766056558, -0.8480230614712401, -1.0654785480987181, -0.9512333387964199, -0.9739877728099025], "text": ["instagram URL: http://instagram.com/web/friendships/1280794066/follow/<br>instagram ID: 1280794066<br>final measure: 0.53<br>likes: 1322543.0<br>followers: 253193.0<br>likesperday: 7602.0<br>", "instagram URL: http://instagram.com/web/friendships/550862816/follow/<br>instagram ID: 550862816<br>final
# ...
